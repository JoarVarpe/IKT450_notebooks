# %%
 # %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import json
pic= "/home/jaoi/schoolshit/notebooks/IKT450/balloon/train/34020010494_e5cb88e1c4_k.jpg"
x_coor = [1020, 1000, 994,
                  1003,
                  1023,
                  1050,
                  1089,
                  1134,
                  1190,
                  1265,
                  1321,
                  1361,
                  1403,
                  1428,
                  1442,
                  1445,
                  1441,
                  1427,
                  1400,
                  1361,
                  1316,
                  1269,
                  1228,
                  1198,
                  1207,
                  1210,
                  1190,
                  1177,
                  1172,
                  1174,
                  1170,
                  1153,
                  1127,
                  1104,
                  1061,
                  1032,
                  1020]
y_coor = [963,
                  899,
                  841,
                  787,
                  738,
                  700,
                  663,
                  638,
                  621,
                  619,
                  643,
                  672,
                  720,
                  765,
                  800,
                  860,
                  896,
                  942,
                  990,
                  1035,
                  1079,
                  1112,
                  1129,
                  1134,
                  1144,
                  1153,
                  1166,
                  1166,
                  1150,
                  1136,
                  1129,
                  1122,
                  1112,
                  1084,
                  1037,
                  989,
                  963]
xy = list(zip(x_coor, y_coor))
print(xy)
# Out:
# [(1020, 963), (1000, 899), (994, 841), (1003, 787), (1023, 738), (1050, 700), (1089, 663), (1134, 638), (1190, 621), (1265, 619), (1321, 643), (1361, 672), (1403, 720), (1428, 765), (1442, 800), (1445, 860), (1441, 896), (1427, 942), (1400, 990), (1361, 1035), (1316, 1079), (1269, 1112), (1228, 1129), (1198, 1134), (1207, 1144), (1210, 1153), (1190, 1166), (1177, 1166), (1172, 1150), (1174, 1136), (1170, 1129), (1153, 1122), (1127, 1112), (1104, 1084), (1061, 1037), (1032, 989), (1020, 963)]

# %%
img = mpimg.imread(pic)
imgplot = plt.imshow(img)
plt.scatter(x_coor, y_coor, c="red")

# %%
bloon_coor = None
the_json = "/home/jaoi/schoolshit/notebooks/IKT450/balloon/train/via_region_data.json"
with open(the_json) as fp:
    bloon_coor = json.load(fp)
print(json.dumps(bloon_coor, indent=4, sort_keys=True))
# Out:
# {
#     "10464445726_6f1e3bbe6a_k.jpg712154": {
#         "base64_img_data": "",
#         "file_attributes": {},
#         "filename": "10464445726_6f1e3bbe6a_k.jpg",
#         "fileref": "",
#         "regions": {
#             "0": {
#                 "region_attributes": {},
#                 "shape_attributes": {
#                     "all_points_x": [
#                         1757,
#                         1772,
#                         1787,
#                         1780,
#                         1764,
#                         1739,
#                         1708,
#                         1655,
#                         1615,
#                         1556,
#                         1506,
#                         1437,
#                         1381,
#                         1327,
#                         1293,
#                         1252,
#                         1220,
#                         1217,
#                         1202,
# ...

# %%
for k in bloon_coor:
    if len(bloon_coor[k]["regions"]) > 0:
        print(bloon_coor[k]["regions"])
# Out:
# {'0': {'shape_attributes': {'name': 'polygon', 'all_points_x': [1020, 1000, 994, 1003, 1023, 1050, 1089, 1134, 1190, 1265, 1321, 1361, 1403, 1428, 1442, 1445, 1441, 1427, 1400, 1361, 1316, 1269, 1228, 1198, 1207, 1210, 1190, 1177, 1172, 1174, 1170, 1153, 1127, 1104, 1061, 1032, 1020], 'all_points_y': [963, 899, 841, 787, 738, 700, 663, 638, 621, 619, 643, 672, 720, 765, 800, 860, 896, 942, 990, 1035, 1079, 1112, 1129, 1134, 1144, 1153, 1166, 1166, 1150, 1136, 1129, 1122, 1112, 1084, 1037, 989, 963]}, 'region_attributes': {}}}
# {'0': {'shape_attributes': {'name': 'polygon', 'all_points_x': [586, 510, 441, 389, 331, 268, 196, 158, 135, 156, 210, 307, 403, 437, 443, 425, 448, 481, 506, 513, 503, 511, 502, 583, 669, 755, 800, 811, 803, 784, 755, 717, 668, 620, 586], 'all_points_y': [133, 116, 115, 126, 149, 185, 261, 339, 438, 560, 664, 784, 868, 893, 929, 964, 964, 961, 965, 958, 936, 910, 896, 836, 752, 636, 538, 454, 392, 329, 270, 220, 175, 149, 133]}, 'region_attributes': {}}}
# ...
